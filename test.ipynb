# %%
import numpy as np
from Library import query_box

# %%
points = np.random.rand(10000, 2)


center = np.array([0.5, 0.5])
dimensions = np.array([0.1, 0.1])

indx = query_box(points, center, dimensions)

# %%
points_in_box = points[indx]


#plot

import matplotlib.pyplot as plt

plt.scatter(points[:,0], points[:,1], s = 0.1)
plt.scatter(points_in_box[:,0], points_in_box[:,1], s = 0.1)

plt.show()
